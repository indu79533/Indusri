# %% [markdown]
# <a href="https://colab.research.google.com/github/indu79533/Indusri/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.array([[1], [2], [3], [4], [5]])  # Independent variable
Y = np.array([1, 2, 2.5, 4, 5])  # Dependent variable

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')
plt.plot(X, Y_pred, color='red')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): -0.10000000000000009
# Coefficient (β1): [1.]

# %%
X = np.random.rand(100, 1) * 100  # 100 random numbers between 0 and 100
Y = 2 * X + np.random.randn(100, 1) * 10  # Linear relation with some noise

# %%
plt.scatter(X, Y, color='blue')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')  # Actual data points
plt.plot(X, Y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): -0.10000000000000009
# Coefficient (β1): [1.]

# %%
import pandas as pd

# %%
df=pd.read_csv('https://in.docworkspace.com/d/sIK-VnpHwAfeKgboG?sa=601.1123')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-17-29ab6b087346> in <cell line: 1>()
# ----> 1 df=pd.read_csv('https://in.docworkspace.com/d/sIK-VnpHwAfeKgboG?sa=601.1123')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('https://in.docworkspace.com/d/sIK-VnpHwAfeKgboG?sa=601.1123')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-57ef6a6d77d9> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('https://in.docworkspace.com/d/sIK-VnpHwAfeKgboG?sa=601.1123')
#
# ...

# %%
df
# Out:
#                                                                                                                                                                                                             <!doctype html>
# <html data-n-head-ssr env="production" time="11... 1:52:21 AM" lang="en-US" data-n-head="%7B%22env... %22time%22:%7B%22ssr%22:%2211/22/2024              %201:52:21%20AM%22%7D  %22lang%22:%7B%22ssr%22:%22en-US%22%7D%7D">
#   <head >                                          NaN                                                NaN                                                NaN                                                            NaN
#     <title>WPS 365</title><meta data-n-head="ss... initial-scale=1"><link data-n-head="ssr" rel="i... opacity .4s;background-color:##f7f7f7;z-index:9... NaN                                                            NaN
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/kgsb24/rishi-college/blob/main/datasets/diabetes.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-29-1e408a3f178b> in <cell line: 1>()
# ----> 1 df = pd.read_csv('https://github.com/kgsb24/rishi-college/blob/main/datasets/diabetes.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#                                                                                                                                                                                                             <!doctype html>
# <html data-n-head-ssr env="production" time="11... 1:52:21 AM" lang="en-US" data-n-head="%7B%22env... %22time%22:%7B%22ssr%22:%2211/22/2024              %201:52:21%20AM%22%7D  %22lang%22:%7B%22ssr%22:%22en-US%22%7D%7D">
#   <head >                                          NaN                                                NaN                                                NaN                                                            NaN
#     <title>WPS 365</title><meta data-n-head="ss... initial-scale=1"><link data-n-head="ssr" rel="i... opacity .4s;background-color:##f7f7f7;z-index:9... NaN                                                            NaN
# ...
